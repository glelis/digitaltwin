# %%
import pandas as pd
import numpy as np
import time
import os
import json

# %run ..\..\..\funcoes_base_global\funcoes_eficiencia.py
# %run ..\..\..\funcoes_base_global\mount_dataframe_from_files.py

# %%
input_path  = os.path.join('out','')
output_path = os.path.join('out','')
if not os.path.exists(output_path): 
    os.mkdir(output_path)

# %%
json_path = os.path.join('..','..','..','funcoes_base_global','tags_description.json')
json_file = open(json_path)
json_str = json_file.read()
tags_description = json.loads(json_str)

# %%
compressor  =  '302A'

# %%
tags_description[compressor]
# Out:
# {'Vibracao': {'XI3403.PV': 'VIB VERTICAL 1o ESTAGIO',
#   'XI3404.PV': 'VIB HORIZONTAL 1o ESTAGIO',
#   'XI3405.PV': 'VIB VERTICAL 2o ESTAGIO',
#   'XI3406.PV': 'VIB HORIZONTAL 2o ESTAGIO'},
#  'Temperatura': {'TI3401.PV': 'TEMP DESCARGA 1o ESTAGIO_1',
#   'TI3402.PV': 'TEMP DESCARGA 1o ESTAGIO_2',
#   'TI3403.PV': 'TEMP DESCARGA 2o ESTAGIO_1',
#   'TI3404.PV': 'TEMP DESCARGA 2o ESTAGIO_2',
#   'TI3409.PV': 'TEMP SUCCAO 2o ESTAGIO',
#   'TI3410.PV': 'TEMP OLEO',
#   'TI3411A.PV': 'ENROLAMENTO A',
#   'TI3411B.PV': 'ENROLAMENTO B',
#   'TI3411C.PV': 'ENROLAMENTO C',
#   'TI3412A.PV': 'MANCAL D.E.',
#   'TI3412B.PV': 'MANCAL N.D.E.'},
#  'Pressao': {'PDI3413.PV': 'PRESSAO OLEO',
#   'PI3401.PV': 'PRESSAO FLUSH',
#   'PI3406.PV': 'PRESSAO DESCARGA 2o ESTAGIO',
#   'PI3417.PV': 'PRESSAO SUCCAO 2o ESTAGIO',
#   'PIC3002.PV': 'PRESSAO SUCCAO 1o ESTAGIO'},
#  'Potencia': {'JI3401.PV': 'POTENCIA CONS'},
#  'Gas': {'AI25121.PV': 'CONCENTRACAO ETENO',
#   'AI25131.PV': 'CONCENTRACAO ETANO',
#   'AI25141.PV': 'CONCENTRACAO PROPENO',
#   'AI25151.PV': 'CONCENTRACAO PROPANO',
#   'AI25161.PV': 'CONCENTRACAO BUTENO',
#   'AI25181.PV': 'CONCENTRACAO BUTANO',
#   'AI25171.PV': 'CONCENTRACAO HEXENO',
#   'AI25191.PV': 'CONCENTRACAO HEXANO',
#   'AI25211.PV': 'CONCENTRACAO H2'},
#  'Vazao': {'FI2601V.PV': 'VAZAO MASSICA',
#   'FI3402.PV': 'VAZAO FLUSH',
#   'FIC2601.PV': 'VAZAO COMPRESSOR'}}

# %%
primeiro_estagio = {  'qtd_cilindros': 1 ,
                     'cilindros_lubrificados' : 0,
                     'qtd_efeitos' : 2,
                     'diametro_cilindro' :490,
                     'curso_pistao' : 160,
                     'diametro_haste' : 75,
                     'clearance' : 12.5,
                     'rpm' : 710,
                     'vol_deslc_cilindro' : 0,
                     'vazao_volumetrica' : 0,
                     'vel_pistao' : 0}

segundo_estagio = {  'qtd_cilindros': 2 ,
                     'cilindros_lubrificados' : 0,
                     'qtd_efeitos' : 2,
                     'diametro_cilindro' :235,
                     'curso_pistao' : 160,
                     'diametro_haste' : 75,
                     'clearance' : 11.64,
                     'rpm' : 710,
                     'vol_deslc_cilindro' : 0,
                     'vazao_volumetrica' : 0,
                     'vel_pistao' : 0}

# %%
eteno = Chemical('ethylene')
etano = Chemical('ethane')
propeno = Chemical('propene')
propano = Chemical('propane')
buteno = Chemical('butene')
butano = Chemical('butane')
hexeno = Chemical('1-hexene')
hexano = Chemical('hexane')
hidrogenio = Chemical('hydrogen')

tags = [eteno, etano, propeno, propano, buteno, butano, hexeno, hexano, hidrogenio]


   
dados = pd.DataFrame(get_parameters(tags))
dados
# Out:
#   Componentes     Tcs        Pcs        MW  omegas       Cp_g_ID       Cv_g_ID
# 0      ethene  282.34  5041000.0  28.05316  0.0850   1528.578720   1232.196430
# 1      ethane  305.32  4872000.0  30.06904  0.0980   1746.096683   1469.584370
# 2     propene  364.90  4600000.0  42.07974  0.1480   1529.491293   1331.903100
# 3     propane  369.83  4248000.0  44.09562  0.1520   1669.551544   1480.996314
# 4    1-butene  419.50  4020000.0  56.10632  0.1870   1526.480008   1378.288863
# 5      butane  425.12  3796000.0  58.12220  0.1930   1695.883963   1552.832602
# 6    1-hexene  504.00  3210000.0  84.15948  0.2839   1554.450653   1455.656556
# 7      hexane  507.60  3025000.0  86.17536  0.2975   1654.717046   1558.234016
# 8    hydrogen   33.20  1296960.0   2.01588 -0.2200  14302.410762  10177.929245

# %%
tags = ['CONCENTRACAO ETENO', 'CONCENTRACAO ETANO', 'CONCENTRACAO PROPENO',
        'CONCENTRACAO PROPANO', 'CONCENTRACAO BUTENO', 'CONCENTRACAO HEXENO',
        'CONCENTRACAO BUTANO', 'CONCENTRACAO HEXANO', 'CONCENTRACAO H2']

# %%
data_segundo_estagio = list(dados_compressor(segundo_estagio).values())
data_segundo_estagio
# Out:
# [2,
#  0,
#  2,
#  0.23500000000000001,
#  0.16,
#  0.075,
#  11.64,
#  710,
#  0.013172697996502005,
#  1122.313869301971,
#  3.786666666666667]

# %%
tag_press = ['PI3417.PV', 'PI3406.PV']

tag_temp = ['Temp_Suc_2', 'Temp_Desc_2']

tag_gas = [ 'AI25121.PV',
            'AI25131.PV',
            'AI25141.PV',
            'AI25151.PV',
            'AI25161.PV',
            'AI25171.PV',
            'AI25181.PV',
            'AI25191.PV',
            'AI25211.PV']

files_dir = [input_path+'df_gas.csv.gz',
             input_path+'df_pressao.csv.gz',
             input_path+'df_temp_tratada.csv.gz']

# %%
df = mount_dataframe_from_files(files_dir,tag_gas+tag_press+tag_temp)
# Out:
# AI25121.PV found in out\df_gas.csv.gz
# AI25131.PV found in out\df_gas.csv.gz
# AI25141.PV found in out\df_gas.csv.gz
# AI25151.PV found in out\df_gas.csv.gz
# AI25161.PV found in out\df_gas.csv.gz
# AI25171.PV found in out\df_gas.csv.gz
# AI25181.PV found in out\df_gas.csv.gz
# AI25191.PV found in out\df_gas.csv.gz
# AI25211.PV found in out\df_gas.csv.gz
# Usecols do not match columns, columns expected but not found: ['PI3417.PV']
# skiping PI3417.PV for out\df_gas.csv.gz
# Usecols do not match columns, columns expected but not found: ['PI3406.PV']
# skiping PI3406.PV for out\df_gas.csv.gz
# Usecols do not match columns, columns expected but not found: ['Temp_Suc_2']
# skiping Temp_Suc_2 for out\df_gas.csv.gz
# Usecols do not match columns, columns expected but not found: ['Temp_Desc_2']
# skiping Temp_Desc_2 for out\df_gas.csv.gz
# Usecols do not match columns, columns expected but not found: ['AI25121.PV']
# skiping AI25121.PV for out\df_pressao.csv.gz
# Usecols do not match columns, columns expected but not found: ['AI25131.PV']
# skiping AI25131.PV for out\df_pressao.csv.gz
# Usecols do not match columns, columns expected but not found: ['AI25141.PV']
# skiping AI25141.PV for out\df_pressao.csv.gz
# Usecols do not match columns, columns expected but not found: ['AI25151.PV']
# skiping AI25151.PV for out\df_pressao.csv.gz
# Usecols do not match columns, columns expected but not found: ['AI25161.PV']
# skiping AI25161.PV for out\df_pressao.csv.gz
# Usecols do not match columns, columns expected but not found: ['AI25171.PV']
# skiping AI25171.PV for out\df_pressao.csv.gz
# Usecols do not match columns, columns expected but not found: ['AI25181.PV']
# skiping AI25181.PV for out\df_pressao.csv.gz
# Usecols do not match columns, columns expected but not found: ['AI25191.PV']
# skiping AI25191.PV for out\df_pressao.csv.gz
# Usecols do not match columns, columns expected but not found: ['AI25211.PV']
# skiping AI25211.PV for out\df_pressao.csv.gz
# PI3417.PV found in out\df_pressao.csv.gz
# PI3406.PV found in out\df_pressao.csv.gz
# Usecols do not match columns, columns expected but not found: ['Temp_Suc_2']
# skiping Temp_Suc_2 for out\df_pressao.csv.gz
# Usecols do not match columns, columns expected but not found: ['Temp_Desc_2']
# skiping Temp_Desc_2 for out\df_pressao.csv.gz
# Usecols do not match columns, columns expected but not found: ['AI25121.PV']
# skiping AI25121.PV for out\df_temp_tratada.csv.gz
# Usecols do not match columns, columns expected but not found: ['AI25131.PV']
# skiping AI25131.PV for out\df_temp_tratada.csv.gz
# Usecols do not match columns, columns expected but not found: ['AI25141.PV']
# skiping AI25141.PV for out\df_temp_tratada.csv.gz
# Usecols do not match columns, columns expected but not found: ['AI25151.PV']
# skiping AI25151.PV for out\df_temp_tratada.csv.gz
# Usecols do not match columns, columns expected but not found: ['AI25161.PV']
# skiping AI25161.PV for out\df_temp_tratada.csv.gz
# Usecols do not match columns, columns expected but not found: ['AI25171.PV']
# skiping AI25171.PV for out\df_temp_tratada.csv.gz
# Usecols do not match columns, columns expected but not found: ['AI25181.PV']
# skiping AI25181.PV for out\df_temp_tratada.csv.gz
# Usecols do not match columns, columns expected but not found: ['AI25191.PV']
# skiping AI25191.PV for out\df_temp_tratada.csv.gz
# Usecols do not match columns, columns expected but not found: ['AI25211.PV']
# skiping AI25211.PV for out\df_temp_tratada.csv.gz
# Usecols do not match columns, columns expected but not found: ['PI3417.PV']
# skiping PI3417.PV for out\df_temp_tratada.csv.gz
# Usecols do not match columns, columns expected but not found: ['PI3406.PV']
# skiping PI3406.PV for out\df_temp_tratada.csv.gz
# Temp_Suc_2 found in out\df_temp_tratada.csv.gz
# Temp_Desc_2 found in out\df_temp_tratada.csv.gz
# Mounting final DF

# %%
df = df.dropna()

# %% [markdown]
# ### Renomeando Colunas do Dataframe

# %%
for name in list(tags_description[compressor]):
    df.rename(columns=tags_description[compressor][name], inplace = True)
df.columns
# Out:
# Index(['CONCENTRACAO ETENO', 'CONCENTRACAO ETANO', 'CONCENTRACAO PROPENO',
#        'CONCENTRACAO PROPANO', 'CONCENTRACAO BUTENO', 'CONCENTRACAO HEXENO',
#        'CONCENTRACAO BUTANO', 'CONCENTRACAO HEXANO', 'CONCENTRACAO H2',
#        'PRESSAO SUCCAO 2o ESTAGIO', 'PRESSAO DESCARGA 2o ESTAGIO',
#        'Temp_Suc_2', 'Temp_Desc_2'],
#       dtype='object')

# %% [markdown]
# ### Convertendo Variáveis para Pascal e Kelvin

# %%
df['Temp_Suc_2'] = df['Temp_Suc_2'] + 273.15
df['Temp_Desc_2'] = df['Temp_Desc_2'] + 273.15

df['PRESSAO SUCCAO 2o ESTAGIO'] = (df['PRESSAO SUCCAO 2o ESTAGIO'] + 1.01325)*100000   # BAR
df['PRESSAO DESCARGA 2o ESTAGIO'] = (df['PRESSAO DESCARGA 2o ESTAGIO'] + 1.01325)*100000   # BAR G 

df.loc[:, 'CONCENTRACAO ETENO':'CONCENTRACAO H2'] = df.loc[:, 'CONCENTRACAO ETENO':'CONCENTRACAO H2']/100

# %%
df.shape
# Out:
# (2003759, 13)

# %%
df.head()
# Out:
#                      CONCENTRACAO ETENO  CONCENTRACAO ETANO  \
# Date
# 2015-01-06 05:00:00             0.07932               0.003
# 2015-01-06 05:01:00             0.07932               0.003
# 2015-01-06 05:02:00             0.07932               0.003
# 2015-01-06 05:03:00             0.07932               0.003
# 2015-01-06 05:04:00             0.07932               0.003
#
#                      CONCENTRACAO PROPENO  CONCENTRACAO PROPANO  \
# Date
# 2015-01-06 05:00:00               0.00079               0.74417
# 2015-01-06 05:01:00               0.00079               0.74417
# 2015-01-06 05:02:00               0.00079               0.74417
# 2015-01-06 05:03:00               0.00079               0.74417
# 2015-01-06 05:04:00               0.00079               0.74417
#
#                      CONCENTRACAO BUTENO  CONCENTRACAO HEXENO  \
# Date
# 2015-01-06 05:00:00               0.0007                  0.0
# 2015-01-06 05:01:00               0.0007                  0.0
# 2015-01-06 05:02:00               0.0007                  0.0
# 2015-01-06 05:03:00               0.0007                  0.0
# 2015-01-06 05:04:00               0.0007                  0.0
#
#                      CONCENTRACAO BUTANO  CONCENTRACAO HEXANO  \
# Date
# 2015-01-06 05:00:00              0.00068                  0.0
# 2015-01-06 05:01:00              0.00068                  0.0
# 2015-01-06 05:02:00              0.00068                  0.0
# 2015-01-06 05:03:00              0.00068                  0.0
# 2015-01-06 05:04:00              0.00068                  0.0
#
#                      CONCENTRACAO H2  PRESSAO SUCCAO 2o ESTAGIO  \
# Date
# 2015-01-06 05:00:00          0.00000                   548825.0
# 2015-01-06 05:01:00          0.00000                   556125.0
# 2015-01-06 05:02:00          0.00003                   560725.0
# 2015-01-06 05:03:00          0.00003                   564425.0
# 2015-01-06 05:04:00          0.00003                   575025.0
#
#                      PRESSAO DESCARGA 2o ESTAGIO  Temp_Suc_2  Temp_Desc_2
# Date
# 2015-01-06 05:00:00                    1548025.0     306.150     383.1130
# 2015-01-06 05:01:00                    1566425.0     307.145     386.1335
# 2015-01-06 05:02:00                    1587925.0     307.150     387.1445
# 2015-01-06 05:03:00                    1608425.0     308.144     387.6470
# 2015-01-06 05:04:00                    1665825.0     308.150     387.6500

# %%
tags_suc = ['Temp_Suc_2','PRESSAO SUCCAO 2o ESTAGIO']    
tags_desc = ['Temp_Desc_2', 'PRESSAO DESCARGA 2o ESTAGIO']
tags_comp = ['CONCENTRACAO ETENO', 'CONCENTRACAO ETANO', 'CONCENTRACAO PROPENO',
             'CONCENTRACAO PROPANO', 'CONCENTRACAO BUTENO', 'CONCENTRACAO HEXENO',
             'CONCENTRACAO BUTANO', 'CONCENTRACAO HEXANO', 'CONCENTRACAO H2']

start_time = time.time()

result = recorrencia(df.head(5000), dados, data_segundo_estagio, tags_suc,tags_desc, tags_comp)

time_running = time.time()-start_time
print("--- %s minutos ---" % (time_running/60))

result.head()
# Out:
# --- 0.3735921263694763 minutos ---
#                      Ef_Politropica  Head_Politropica  Ef_Isentropica  \
# Date
# 2015-01-06 05:00:00       56.323354         65.470738       53.554824
# 2015-01-06 05:01:00       55.111599         65.784760       52.272738
# 2015-01-06 05:02:00       54.806299         66.194978       51.932313
# 2015-01-06 05:03:00       55.604800         66.726888       52.762689
# 2015-01-06 05:04:00       56.508107         67.653191       53.676778
#
#                      Head_Isentropica     Z_Suc    Z_Desc         MW    T_Suc  \
# Date
# 2015-01-06 05:00:00         62.252575  0.950720  0.932259  42.550343  306.150
# 2015-01-06 05:01:00         62.396113  0.950546  0.933369  42.550343  307.145
# 2015-01-06 05:02:00         62.723782  0.950125  0.933076  42.548876  307.150
# 2015-01-06 05:03:00         63.316297  0.950291  0.932515  42.548876  308.144
# 2015-01-06 05:04:00         64.263440  0.949326  0.930053  42.548876  308.150
#
#                             r         k  Densidade_Suc  Densidade_Desc  \
# Date
# 2015-01-06 05:00:00  2.820617  1.138701       9.649738       22.181106
# 2015-01-06 05:01:00  2.816678  1.138692       9.748193       22.242684
# 2015-01-06 05:02:00  2.831914  1.138777       9.832691       22.495373
# 2015-01-06 05:03:00  2.849670  1.138791       9.863920       22.769959
# 2015-01-06 05:04:00  2.896961  1.138865      10.059185       23.644795
#
#                      Ef_Volumetrica  Pot_Compressao  Pot_Politropica  \
# Date
# 2015-01-06 05:00:00       72.130730       13.069558        17.903504
# 2015-01-06 05:01:00       72.207142       13.435204        18.404389
# 2015-01-06 05:02:00       72.073244       13.569082        18.587784
# 2015-01-06 05:03:00       71.887735       13.446994        18.420540
# 2015-01-06 05:04:00       71.407266       13.326060        18.254877
#
#                      Pot_Isentropica
# Date
# 2015-01-06 05:00:00        17.903504
# 2015-01-06 05:01:00        18.404389
# 2015-01-06 05:02:00        18.587784
# 2015-01-06 05:03:00        18.420540
# 2015-01-06 05:04:00        18.254877

# %%
tags_suc = ['Temp_Suc_2','PRESSAO SUCCAO 2o ESTAGIO']    
tags_desc = ['Temp_Desc_2', 'PRESSAO DESCARGA 2o ESTAGIO']
tags_comp = ['CONCENTRACAO ETENO', 'CONCENTRACAO ETANO', 'CONCENTRACAO PROPENO',
             'CONCENTRACAO PROPANO', 'CONCENTRACAO BUTENO', 'CONCENTRACAO HEXENO',
             'CONCENTRACAO BUTANO', 'CONCENTRACAO HEXANO', 'CONCENTRACAO H2']

start_time = time.time()

result = recorrencia(df, dados, data_segundo_estagio, tags_suc,tags_desc, tags_comp)

time_running = time.time()-start_time
print("--- %s minutos ---" % (time_running/60))

result.head()
# Out:
# --- 147.1465505639712 minutos ---
#                      Ef_Politropica  Head_Politropica  Ef_Isentropica  \
# Date
# 2015-01-06 05:00:00       56.323354         65.470738       53.554824
# 2015-01-06 05:01:00       55.111599         65.784760       52.272738
# 2015-01-06 05:02:00       54.806299         66.194978       51.932313
# 2015-01-06 05:03:00       55.604800         66.726888       52.762689
# 2015-01-06 05:04:00       56.508107         67.653191       53.676778
#
#                      Head_Isentropica     Z_Suc    Z_Desc         MW    T_Suc  \
# Date
# 2015-01-06 05:00:00         62.252575  0.950720  0.932259  42.550343  306.150
# 2015-01-06 05:01:00         62.396113  0.950546  0.933369  42.550343  307.145
# 2015-01-06 05:02:00         62.723782  0.950125  0.933076  42.548876  307.150
# 2015-01-06 05:03:00         63.316297  0.950291  0.932515  42.548876  308.144
# 2015-01-06 05:04:00         64.263440  0.949326  0.930053  42.548876  308.150
#
#                             r         k  Densidade_Suc  Densidade_Desc  \
# Date
# 2015-01-06 05:00:00  2.820617  1.138701       9.649738       22.181106
# 2015-01-06 05:01:00  2.816678  1.138692       9.748193       22.242684
# 2015-01-06 05:02:00  2.831914  1.138777       9.832691       22.495373
# 2015-01-06 05:03:00  2.849670  1.138791       9.863920       22.769959
# 2015-01-06 05:04:00  2.896961  1.138865      10.059185       23.644795
#
#                      Ef_Volumetrica  Pot_Compressao  Pot_Politropica  \
# Date
# 2015-01-06 05:00:00       72.130730       13.069558        17.903504
# 2015-01-06 05:01:00       72.207142       13.435204        18.404389
# 2015-01-06 05:02:00       72.073244       13.569082        18.587784
# 2015-01-06 05:03:00       71.887735       13.446994        18.420540
# 2015-01-06 05:04:00       71.407266       13.326060        18.254877
#
#                      Pot_Isentropica
# Date
# 2015-01-06 05:00:00        17.903504
# 2015-01-06 05:01:00        18.404389
# 2015-01-06 05:02:00        18.587784
# 2015-01-06 05:03:00        18.420540
# 2015-01-06 05:04:00        18.254877

# %%
result.to_csv(output_path+'df_eficiencia.csv.gz', compression = 'gzip')
