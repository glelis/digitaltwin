# %% [markdown]
# ## 0. TAGS RECEBIDAS

# %% [markdown]
# O objetivo desse notebook é ler as tags, separá-las em grupos (ex tags de pressão, de temperatura, etc) e, por fim, analisá-las. Também verificamos as tags faltantes.
#
# Análises feitas:
# * Tags faltantes
# * Estatísticas: média, máximo, mínimo e percentual de NaN
# * Anos das tags
# * Qualidade: quantidade de dados bons e ruins

# %%
import pandas as pd
import os
import time
import missingno as msno
import numpy as np
# bibliotecas de visualização
import seaborn as sns
import matplotlib.pyplot as plt

# importando funções de 'read_tags.py'
# %run ..\..\..\funcoes_base_global\read_tags.py

# %%
# setando parâmetros para padronizar os plots
plt.rcParams['font.weight'] = 'bold'
plt.rcParams['figure.titlesize'] = 20
plt.rcParams['figure.titleweight'] = 'bold'
plt.rcParams['axes.titlesize'] = 20
plt.rcParams['axes.titleweight'] = 'bold'
plt.rcParams['axes.labelsize'] = 18
plt.rcParams['axes.labelweight'] = 'bold'
plt.rcParams['xtick.labelsize'] = 14
plt.rcParams['ytick.labelsize'] = 14

# %% [markdown]
# ### 1. Definindo funções auxiliadoras

# %%
def path(name):
    path = os.path.join('..','..','1_dados_raw','sensores','out', name)
    return(path)

def path_2(name):
    path = os.path.join('..','..','1_dados_raw','excel', name)
    return(path)

def path_3(name):
    path = os.path.join('out', name)
    return(path)

# %%
def estatisticas(df):
    "Cria dataframe cujas colunas são média, máximo, mínimo e % de NaN por tag"
    media = df[df.columns[0:]].mean()
    maximo = df[df.columns[0:]].max()
    minimo = df[df.columns[0:]].min()
    percentNan = df[df.columns[0:]].isna().sum() / df.shape[0] * 100
    
    stats = pd.concat([media,minimo,maximo,percentNan],axis=1)
    stats.columns = ['mean','min','max','percentNan']
    return stats

# %%
def qualidade(data):
    "Conta quantidade de dados classificados como bons e ruins"
    for tag in data.columns[data.columns.str.contains('_quality')]:
        total = data[tag].count()
        good = data[tag][data[tag] == 'Good'].count()
        bad = data[tag][data[tag] == 'Bad'].count()
        print(tag)
        print('Qtd good: %d       Qtd bad: %d       Good Percent: %.2f \n'%(good, bad, (good/total)*100))

# %% [markdown]
# ### 2. Setando listas de tags

# %%
# Armazena o nome dos todas as tags baixadas
tags_baixadas = os.listdir(path(''))
tags_baixadas = pd.Series(tags_baixadas)
tags_baixadas = tags_baixadas[tags_baixadas.str.contains('.csv.gz')]
tags_baixadas = tags_baixadas.str.split('.csv.gz', expand = True)
tags_baixadas = tags_baixadas.drop(1, axis = 1).reset_index(drop = True)
tags_baixadas = tags_baixadas.rename(columns = {0 : 'Tags'})
tags_baixadas = tags_baixadas['Tags'].str.split('_', expand = True)[0]
#tags_baixadas = tags_baixadas[0].tolist()

# %%
# Armazena as tags solicitadas para extração
name = 'TAGS.xlsx'
tags_solicitadas = pd.read_excel(path_2(name))
tags_solicitadas['Tags'] = tags_solicitadas['Tags'].str.strip()
#tags_solicitadas = tags_solicitadas['Tags'].tolist()

# %%
tags_baixadas = list(tags_baixadas)

# %%
# Verificando tags faltantes
tags_faltantes = [x for x in tags_solicitadas['Tags'] if (x not in list(tags_baixadas))]
faltantes = pd.DataFrame(tags_faltantes)
print('TAGS FALTANTES:\n', faltantes)
# Out:
# TAGS FALTANTES:
#              0
# 0  produtopol
# 1      Modelo

# %%
# Salvando as tags faltantes em '1_preprocessamento', 'out'
name = 'tags_faltantes.xlsx'
faltantes.to_excel(path_3(name))

# %% [markdown]
# ### 3. Separando tags em grupos

# %%
vibracao = []
pressao = []
temperatura = []
vazao = []
gas = []
outras = []     # caso seja necessário, abrir em grupos mais específicos

#Remoção de Tags Duplicadas
tags_baixadas = list(dict.fromkeys(tags_baixadas))

#Remoção das Tags de 1S
tags_baixadas = [x for x in tags_baixadas if '1S' not in x]

for tag in tags_baixadas:
    if tag[0] == 'X':
        vibracao.append(tag)
    elif tag[0] == 'P':
        pressao.append(tag)
    elif tag[0] == 'T':
        temperatura.append(tag)
    elif tag[0] == 'F':
        vazao.append(tag)
    elif tag[0] == 'A':
        gas.append(tag)
    else:
        outras.append(tag)

# %% [markdown]
# ### 4. Temperatura

# %% [markdown]
# #### 4.1. Lendo as tags

# %%
df = read_tags(temperatura, path(''))
df.to_csv(path_3('df_temp.csv.gz'), compression = 'gzip')
# Out:
# Processando TAG: TI2401.PV
# Processando TAG: TI2601.PV
# Processando TAG: TI3401.PV
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3296: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Processando TAG: TI3402.PV
# Processando TAG: TI3403.PV
# Processando TAG: TI3404.PV
# Processando TAG: TI3405.PV
# Processando TAG: TI3406.PV
# Processando TAG: TI3407.PV
# Processando TAG: TI3408.PV
# Processando TAG: TI3409.PV
# Processando TAG: TI3410.PV
# Processando TAG: TI3411A.PV
# Processando TAG: TI3411B.PV
# Processando TAG: TI3411C.PV
# Processando TAG: TI3412A.PV
# Processando TAG: TI3412B.PV
# Concatenando...
# Feito!

# %%
df.head().dropna()
# Out:
# Empty DataFrame
# Columns: [TI2401.PV, TI2401.PV_quality, TI2601.PV, TI2601.PV_quality, TI3401.PV, TI3401.PV_quality, TI3401.PV, TI3401.PV_quality, TI3402.PV, TI3402.PV_quality, TI3402.PV, TI3402.PV_quality, TI3403.PV, TI3403.PV_quality, TI3403.PV, TI3403.PV_quality, TI3404.PV, TI3404.PV_quality, TI3404.PV, TI3404.PV_quality, TI3405.PV, TI3405.PV_quality, TI3406.PV, TI3406.PV_quality, TI3407.PV, TI3407.PV_quality, TI3408.PV, TI3408.PV_quality, TI3409.PV, TI3409.PV_quality, TI3409.PV, TI3409.PV_quality, TI3410.PV, TI3410.PV_quality, TI3410.PV, TI3410.PV_quality, TI3411A.PV, TI3411A.PV_quality, TI3411A.PV, TI3411A.PV_quality, TI3411B.PV, TI3411B.PV_quality, TI3411B.PV, TI3411B.PV_quality, TI3411C.PV, TI3411C.PV_quality, TI3411C.PV, TI3411C.PV_quality, TI3412A.PV, TI3412A.PV_quality, TI3412A.PV, TI3412A.PV_quality, TI3412B.PV, TI3412B.PV_quality, TI3412B.PV, TI3412B.PV_quality]
# Index: []
#
# [0 rows x 56 columns]

# %% [markdown]
# #### 4.2. Análises estatísticas

# %%
df[df.columns[~df.columns.str.contains('_quality')]].dropna()
# Out:
#                      TI2401.PV  TI2601.PV  TI3401.PV  TI3402.PV  TI3403.PV  \
# Date
# 2015-01-01 00:00:00    27.1025    23.5897     35.000     27.000     28.000
# 2015-01-01 00:01:00    27.1084    23.4432     35.000     27.000     28.000
# 2015-01-01 00:02:00    27.1025    23.5311     35.000     27.000     28.000
# 2015-01-01 00:03:00    27.1025    23.4432     35.000     27.000     28.000
# 2015-01-01 00:04:00    27.0908    23.4432     35.000     27.000     28.000
# 2015-01-01 00:05:00    27.0908    23.4432     35.000     27.000     28.000
# 2015-01-01 00:06:00    27.0791    23.6190     35.000     27.000     28.000
# 2015-01-01 00:07:00    27.0791    23.4432     35.000     27.000     28.000
# 2015-01-01 00:08:00    27.0674    23.5311     35.000     27.000     28.000
# 2015-01-01 00:09:00    27.0615    23.4432     35.000     27.000     28.000
# 2015-01-01 00:10:00    27.0674    23.5897     35.000     27.000     28.000
# 2015-01-01 00:11:00    27.0674    23.4432     35.000     27.000     28.000
# 2015-01-01 00:12:00    27.0439    23.4725     35.000     27.000     28.000
# 2015-01-01 00:13:00    27.0439    23.4432     35.000     27.000     28.000
# 2015-01-01 00:14:00    27.0439    23.4432     35.000     27.000     28.000
# 2015-01-01 00:15:00    27.0264    23.4432     34.007     27.000     28.000
# 2015-01-01 00:16:00    27.0322    23.3260     34.000     27.000     28.000
# 2015-01-01 00:17:00    27.0088    23.4432     34.000     27.000     28.000
# 2015-01-01 00:18:00    27.0029    23.4432     34.000     27.000     28.000
# 2015-01-01 00:19:00    27.0146    23.4432     34.000     27.000     28.000
# 2015-01-01 00:20:00    27.0146    23.4432     34.000     27.000     28.000
# 2015-01-01 00:21:00    27.0029    23.4432     34.000     27.000     28.000
# 2015-01-01 00:22:00    26.9854    23.4432     34.000     27.000     28.000
# 2015-01-01 00:23:00    26.9971    23.4432     34.000     27.000     28.000
# 2015-01-01 00:24:00    26.9678    23.4432     34.000     27.000     28.000
# 2015-01-01 00:25:00    26.9736    23.3553     34.000     27.000     28.000
# 2015-01-01 00:26:00    26.9502    23.4432     34.000     27.000     28.000
# 2015-01-01 00:27:00    26.9678    23.4432     34.000     27.000     28.000
# 2015-01-01 00:28:00    26.9678    23.2674     34.000     27.000     28.000
# 2015-01-01 00:29:00    26.9385    23.4432     34.000     27.000     28.000
# ...                        ...        ...        ...        ...        ...
# 2019-05-01 01:50:00    37.1777    62.2711    114.991    112.000    153.000
# 2019-05-01 01:51:00    37.1572    62.4469    115.000    112.000    153.000
# 2019-05-01 01:52:00    37.1572    62.6227    114.012    112.000    152.012
# 2019-05-01 01:53:00    37.1777    62.0952    114.988    112.000    152.988
# 2019-05-01 01:54:00    37.1631    62.2711    114.008    112.000    153.000
# 2019-05-01 01:55:00    37.1455    62.3590    114.000    112.000    153.000
# 2019-05-01 01:56:00    37.1279    62.2711    114.993    112.993    153.000
# 2019-05-01 01:57:00    37.1631    62.5641    115.000    113.000    153.000
# 2019-05-01 01:58:00    37.1777    62.2711    115.000    113.000    153.000
# 2019-05-01 01:59:00    37.1455    62.4176    115.000    113.000    153.000
# 2019-05-01 02:00:00    37.1279    62.6813    115.000    113.000    153.000
# 2019-05-01 02:01:00    37.1338    62.4176    115.000    113.000    153.000
# 2019-05-01 02:02:00    37.1631    62.3297    115.000    113.000    153.000
# 2019-05-01 02:03:00    37.2129    62.4469    115.000    113.000    153.000
# 2019-05-01 02:04:00    37.2012    62.4469    115.000    112.006    153.000
# 2019-05-01 02:05:00    37.2012    62.5348    115.000    112.993    153.000
# 2019-05-01 02:06:00    37.1777    62.5641    115.000    112.008    153.000
# 2019-05-01 02:07:00    37.1895    62.5348    115.000    112.000    152.012
# 2019-05-01 02:08:00    37.2129    62.5641    115.000    112.000    152.990
# 2019-05-01 02:09:00    37.2129    62.4469    115.000    112.000    152.009
# 2019-05-01 02:10:00    37.1777    62.5641    114.009    112.000    152.991
# 2019-05-01 02:11:00    37.1631    62.4176    114.993    112.000    153.000
# 2019-05-01 02:12:00    37.1895    62.4469    114.010    112.990    153.000
# 2019-05-01 02:13:00    37.2012    62.0952    114.990    113.000    153.000
# 2019-05-01 02:14:00    37.1953    62.4469    115.000    113.000    153.000
# 2019-05-01 02:15:00    37.2129    62.5641    115.000    113.000    153.000
# 2019-05-01 02:16:00    37.2012    62.4469    115.000    113.000    153.000
# 2019-05-01 02:17:00    37.2188    62.4469    115.000    113.000    153.000
# 2019-05-01 02:18:00    37.2480    62.4469    115.000    113.000    153.000
# 2019-05-01 02:19:00    37.3008    62.4469    115.000    113.000    153.000
#
#                      TI3404.PV  TI3405.PV  TI3406.PV  TI3407.PV  TI3408.PV  \
# Date
# 2015-01-01 00:00:00     28.000        0.0        0.0     89.866        0.0
# 2015-01-01 00:01:00     28.000        0.0        0.0     89.866        0.0
# 2015-01-01 00:02:00     28.000        0.0        0.0     89.866        0.0
# 2015-01-01 00:03:00     28.000        0.0        0.0     89.866        0.0
# 2015-01-01 00:04:00     28.000        0.0        0.0     89.866        0.0
# 2015-01-01 00:05:00     28.000        0.0        0.0     89.866        0.0
# 2015-01-01 00:06:00     28.000        0.0        0.0     89.866        0.0
# 2015-01-01 00:07:00     28.000        0.0        0.0     89.866        0.0
# 2015-01-01 00:08:00     28.000        0.0        0.0     89.866        0.0
# 2015-01-01 00:09:00     28.000        0.0        0.0     89.866        0.0
# 2015-01-01 00:10:00     28.000        0.0        0.0     89.866        0.0
# 2015-01-01 00:11:00     28.000        0.0        0.0     89.866        0.0
# 2015-01-01 00:12:00     28.000        0.0        0.0     89.866        0.0
# 2015-01-01 00:13:00     28.000        0.0        0.0     89.866        0.0
# 2015-01-01 00:14:00     28.000        0.0        0.0     89.866        0.0
# 2015-01-01 00:15:00     28.000        0.0        0.0     89.866        0.0
# 2015-01-01 00:16:00     28.000        0.0        0.0     89.866        0.0
# 2015-01-01 00:17:00     28.000        0.0        0.0     89.866        0.0
# 2015-01-01 00:18:00     28.000        0.0        0.0     89.866        0.0
# 2015-01-01 00:19:00     28.000        0.0        0.0     89.866        0.0
# 2015-01-01 00:20:00     28.000        0.0        0.0     89.866        0.0
# 2015-01-01 00:21:00     28.000        0.0        0.0     89.866        0.0
# 2015-01-01 00:22:00     28.000        0.0        0.0     89.866        0.0
# 2015-01-01 00:23:00     28.000        0.0        0.0     89.866        0.0
# 2015-01-01 00:24:00     28.000        0.0        0.0     89.866        0.0
# 2015-01-01 00:25:00     28.000        0.0        0.0     89.866        0.0
# 2015-01-01 00:26:00     28.000        0.0        0.0     89.866        0.0
# 2015-01-01 00:27:00     28.000        0.0        0.0     89.866        0.0
# 2015-01-01 00:28:00     28.000        0.0        0.0     89.866        0.0
# 2015-01-01 00:29:00     28.000        0.0        0.0     89.866        0.0
# ...                        ...        ...        ...        ...        ...
# 2019-05-01 01:50:00    156.000        0.0        0.0      0.000        0.0
# 2019-05-01 01:51:00    156.000        0.0        0.0      0.000        0.0
# 2019-05-01 01:52:00    156.000        0.0        0.0      0.000        0.0
# 2019-05-01 01:53:00    156.000        0.0        0.0      0.000        0.0
# 2019-05-01 01:54:00    156.000        0.0        0.0      0.000        0.0
# 2019-05-01 01:55:00    156.000        0.0        0.0      0.000        0.0
# 2019-05-01 01:56:00    156.993        0.0        0.0      0.000        0.0
# 2019-05-01 01:57:00    157.000        0.0        0.0      0.000        0.0
# 2019-05-01 01:58:00    156.011        0.0        0.0      0.000        0.0
# 2019-05-01 01:59:00    156.992        0.0        0.0      0.000        0.0
# 2019-05-01 02:00:00    157.000        0.0        0.0      0.000        0.0
# 2019-05-01 02:01:00    157.000        0.0        0.0      0.000        0.0
# 2019-05-01 02:02:00    156.006        0.0        0.0      0.000        0.0
# 2019-05-01 02:03:00    156.000        0.0        0.0      0.000        0.0
# 2019-05-01 02:04:00    156.000        0.0        0.0      0.000        0.0
# 2019-05-01 02:05:00    156.000        0.0        0.0      0.000        0.0
# 2019-05-01 02:06:00    156.000        0.0        0.0      0.000        0.0
# 2019-05-01 02:07:00    156.000        0.0        0.0      0.000        0.0
# 2019-05-01 02:08:00    156.000        0.0        0.0      0.000        0.0
# 2019-05-01 02:09:00    156.000        0.0        0.0      0.000        0.0
# 2019-05-01 02:10:00    156.000        0.0        0.0      0.000        0.0
# 2019-05-01 02:11:00    156.000        0.0        0.0      0.000        0.0
# 2019-05-01 02:12:00    156.000        0.0        0.0      0.000        0.0
# 2019-05-01 02:13:00    156.990        0.0        0.0      0.000        0.0
# 2019-05-01 02:14:00    156.007        0.0        0.0      0.000        0.0
# 2019-05-01 02:15:00    156.000        0.0        0.0      0.000        0.0
# 2019-05-01 02:16:00    156.988        0.0        0.0      0.000        0.0
# 2019-05-01 02:17:00    156.009        0.0        0.0      0.000        0.0
# 2019-05-01 02:18:00    156.000        0.0        0.0      0.000        0.0
# 2019-05-01 02:19:00    156.992        0.0        0.0      0.000        0.0
#
#                      TI3409.PV  TI3410.PV  TI3411A.PV  TI3411B.PV  TI3411C.PV  \
# Date
# 2015-01-01 00:00:00     26.027       37.0      32.000      32.000      30.000
# 2015-01-01 00:01:00     23.019       37.0      32.000      32.000      30.000
# 2015-01-01 00:02:00     26.976       37.0      32.000      32.000      29.006
# 2015-01-01 00:03:00     26.006       37.0      32.000      32.000      29.994
# 2015-01-01 00:04:00     21.027       37.0      32.000      32.000      30.000
# 2015-01-01 00:05:00     19.012       37.0      32.000      32.000      30.000
# 2015-01-01 00:06:00     19.994       37.0      32.000      32.000      29.006
# 2015-01-01 00:07:00     20.994       37.0      32.000      32.000      29.994
# 2015-01-01 00:08:00     19.012       37.0      32.000      32.000      30.000
# 2015-01-01 00:09:00     18.006       37.0      32.000      32.000      29.006
# 2015-01-01 00:10:00     20.981       37.0      32.000      32.000      29.000
# 2015-01-01 00:11:00     22.986       37.0      32.000      32.000      29.000
# 2015-01-01 00:12:00     29.956       37.0      32.000      32.000      29.000
# 2015-01-01 00:13:00     30.994       37.0      32.000      32.000      29.000
# 2015-01-01 00:14:00     30.006       37.0      32.000      32.000      29.000
# 2015-01-01 00:15:00     30.000       37.0      32.000      32.000      29.000
# 2015-01-01 00:16:00     30.000       37.0      32.000      32.000      29.993
# 2015-01-01 00:17:00     23.047       37.0      32.000      32.000      29.007
# 2015-01-01 00:18:00     25.980       37.0      32.000      32.000      29.000
# 2015-01-01 00:19:00     19.049       37.0      32.000      32.000      29.000
# 2015-01-01 00:20:00     19.000       37.0      32.000      32.000      29.000
# 2015-01-01 00:21:00     20.987       37.0      32.000      32.000      29.000
# 2015-01-01 00:22:00     19.013       37.0      32.000      32.000      29.993
# 2015-01-01 00:23:00     19.993       37.0      32.000      32.000      29.007
# 2015-01-01 00:24:00     19.007       37.0      32.000      32.000      29.993
# 2015-01-01 00:25:00     20.985       37.0      32.000      32.000      29.008
# 2015-01-01 00:26:00     19.009       37.0      32.000      32.000      29.000
# 2015-01-01 00:27:00     20.989       37.0      32.000      32.000      29.000
# 2015-01-01 00:28:00     20.004       37.0      32.000      32.000      29.000
# 2015-01-01 00:29:00     17.014       37.0      32.000      32.000      29.000
# ...                        ...        ...         ...         ...         ...
# 2019-05-01 01:50:00     44.000       49.0      74.009      81.000      78.000
# 2019-05-01 01:51:00     44.000       49.0      72.018      79.018      78.991
# 2019-05-01 01:52:00     44.000       49.0      74.965      80.977      78.012
# 2019-05-01 01:53:00     44.000       49.0      73.025      80.012      79.975
# 2019-05-01 01:54:00     44.000       49.0      74.983      77.025      77.025
# 2019-05-01 01:55:00     44.000       49.0      75.990      80.962      77.000
# 2019-05-01 01:56:00     44.000       49.0      72.027      77.027      78.986
# 2019-05-01 01:57:00     44.000       49.0      72.988      77.000      78.012
# 2019-05-01 01:58:00     44.000       49.0      75.967      77.989      76.022
# 2019-05-01 01:59:00     44.000       49.0      72.034      78.000      78.975
# 2019-05-01 02:00:00     44.000       49.0      72.990      77.010      78.010
# 2019-05-01 02:01:00     44.000       49.0      73.000      79.980      78.993
# 2019-05-01 02:02:00     44.000       49.0      72.006      76.024      78.006
# 2019-05-01 02:03:00     44.000       49.0      73.986      76.000      77.007
# 2019-05-01 02:04:00     44.000       49.0      72.011      77.989      78.989
# 2019-05-01 02:05:00     44.000       49.0      72.000      76.013      79.000
# 2019-05-01 02:06:00     44.000       49.0      72.000      77.985      79.000
# 2019-05-01 02:07:00     44.000       49.0      75.952      78.000      77.024
# 2019-05-01 02:08:00     44.000       49.0      72.039      77.010      78.980
# 2019-05-01 02:09:00     44.000       49.0      74.974      80.965      78.009
# 2019-05-01 02:10:00     44.000       49.0      75.991      80.009      77.009
# 2019-05-01 02:11:00     44.000       49.0      76.000      78.014      77.000
# 2019-05-01 02:12:00     44.000       49.0      73.031      77.010      77.990
# 2019-05-01 02:13:00     44.000       49.0      75.969      77.990      77.010
# 2019-05-01 02:14:00     44.000       49.0      75.007      80.978      77.993
# 2019-05-01 02:15:00     44.000       49.0      75.000      77.046      77.011
# 2019-05-01 02:16:00     44.000       49.0      74.012      79.963      78.975
# 2019-05-01 02:17:00     44.000       49.0      75.981      80.991      78.009
# 2019-05-01 02:18:00     44.000       49.0      76.000      81.000      78.000
# 2019-05-01 02:19:00     44.000       49.0      74.017      76.042      78.000
#
#                      TI3412A.PV  TI3412B.PV
# Date
# 2015-01-01 00:00:00       8.000      22.000
# 2015-01-01 00:01:00       8.000      22.000
# 2015-01-01 00:02:00       8.000      22.000
# 2015-01-01 00:03:00       8.000      22.000
# 2015-01-01 00:04:00       8.000      22.000
# 2015-01-01 00:05:00       8.000      22.000
# 2015-01-01 00:06:00       8.000      22.000
# 2015-01-01 00:07:00       8.000      22.000
# 2015-01-01 00:08:00       8.000      22.000
# 2015-01-01 00:09:00       8.000      22.000
# 2015-01-01 00:10:00       8.000      22.000
# 2015-01-01 00:11:00       8.000      22.000
# 2015-01-01 00:12:00       8.000      22.000
# 2015-01-01 00:13:00       8.000      22.000
# 2015-01-01 00:14:00       8.000      22.000
# 2015-01-01 00:15:00       8.000      22.000
# 2015-01-01 00:16:00       8.000      22.000
# 2015-01-01 00:17:00       8.000      22.000
# 2015-01-01 00:18:00       8.000      22.000
# 2015-01-01 00:19:00       8.000      22.000
# 2015-01-01 00:20:00       8.000      22.000
# 2015-01-01 00:21:00       8.000      22.000
# 2015-01-01 00:22:00       8.000      22.000
# 2015-01-01 00:23:00       8.000      22.000
# 2015-01-01 00:24:00       8.000      22.000
# 2015-01-01 00:25:00       8.000      22.000
# 2015-01-01 00:26:00       8.000      22.000
# 2015-01-01 00:27:00       8.000      22.000
# 2015-01-01 00:28:00       8.000      22.000
# 2015-01-01 00:29:00       8.000      22.000
# ...                         ...         ...
# 2019-05-01 01:50:00      63.000      44.000
# 2019-05-01 01:51:00      63.000      44.000
# 2019-05-01 01:52:00      63.000      44.000
# 2019-05-01 01:53:00      63.000      44.988
# 2019-05-01 01:54:00      63.000      44.008
# 2019-05-01 01:55:00      63.000      44.990
# 2019-05-01 01:56:00      63.000      45.000
# 2019-05-01 01:57:00      63.000      44.012
# 2019-05-01 01:58:00      63.000      44.989
# 2019-05-01 01:59:00      63.000      45.000
# 2019-05-01 02:00:00      63.000      45.000
# 2019-05-01 02:01:00      63.000      45.000
# 2019-05-01 02:02:00      63.000      45.000
# 2019-05-01 02:03:00      63.000      45.000
# 2019-05-01 02:04:00      63.000      45.000
# 2019-05-01 02:05:00      63.000      45.000
# 2019-05-01 02:06:00      63.000      45.000
# 2019-05-01 02:07:00      63.000      45.000
# 2019-05-01 02:08:00      63.000      44.010
# 2019-05-01 02:09:00      63.000      44.000
# 2019-05-01 02:10:00      63.000      44.991
# 2019-05-01 02:11:00      63.000      45.000
# 2019-05-01 02:12:00      63.990      45.000
# 2019-05-01 02:13:00      64.000      45.000
# 2019-05-01 02:14:00      63.007      45.000
# 2019-05-01 02:15:00      63.989      45.000
# 2019-05-01 02:16:00      63.012      45.000
# 2019-05-01 02:17:00      63.000      45.000
# 2019-05-01 02:18:00      63.000      45.000
# 2019-05-01 02:19:00      63.992      45.000
#
# [2270784 rows x 17 columns]

# %%
estatisticas(df[df.columns[~df.columns.str.contains('_quality')]])
# Out:
#                   mean       min       max  percentNan
# TI2401.PV    31.896103  -20.9531   60.8906    9.844189
# TI2601.PV    54.520654    0.0000   87.2088    9.844189
# TI3401.PV    96.983157   -4.0000  204.0000   57.781763
# TI3402.PV    96.627039   -6.0000  212.0000   57.781763
# TI3403.PV   133.742164   -4.0000  204.0000   57.781763
# TI3404.PV   129.816393   -6.0000  213.0000   57.781763
# TI3405.PV    27.857973 -240.4460  253.1460    2.604376
# TI3406.PV    15.205652  -62.4240  119.5820    2.604376
# TI3407.PV    24.654939  -63.8230  118.0240    2.604376
# TI3408.PV    36.193839 -177.4440  238.8010    2.604376
# TI3409.PV    46.832898   -4.0000  120.0000   57.781763
# TI3410.PV    52.908773   -6.0000  212.0000   57.781763
# TI3411A.PV   71.273297   -4.0000  120.0000   57.781763
# TI3411B.PV   66.387612   -4.0000  120.0000   57.781763
# TI3411C.PV   61.496080   -4.0000  120.0000   57.781763
# TI3412A.PV   38.210953   -4.0000  120.0000   57.781763
# TI3412B.PV   32.442388   -4.0000  120.0000   57.781763

# %% [markdown]
# #### 4.3. Anos das tags

# %%
# criando um dataframe novo cujo index são os anos
df_ano = df.copy()
df_ano.index = df_ano.index.year

# %%
# removendo as colunas de qualidade
df_ano_numerico = df_ano[df_ano.columns[~df_ano.columns.str.contains('_quality')]]

# %%
tempo = time.time()
sns.heatmap(df_ano_numerico.isnull(), cbar = False)

# %%
time.time() - tempo
# Out:
# 130.56306719779968

# %% [markdown]
# #### 4.4. Análises de qualidade

# %%
qualidade(df)
# Out:
# TI2401.PV_quality
# Qtd good: 4988239       Qtd bad: 49337       Good Percent: 99.02
#
# TI2601.PV_quality
# Qtd good: 4981802       Qtd bad: 55774       Good Percent: 98.89
#
# TI3401.PV_quality
# Qtd good: 2341628       Qtd bad: 29817       Good Percent: 98.74
#
# TI3402.PV_quality
# Qtd good: 2341603       Qtd bad: 29842       Good Percent: 98.74
#
# TI3403.PV_quality
# Qtd good: 2341603       Qtd bad: 29842       Good Percent: 98.74
#
# TI3404.PV_quality
# Qtd good: 2341603       Qtd bad: 29842       Good Percent: 98.74
#
# TI3405.PV_quality
# Qtd good: 1983152       Qtd bad: 3534339       Good Percent: 35.94
#
# TI3406.PV_quality
# Qtd good: 2061655       Qtd bad: 3455836       Good Percent: 37.37
#
# TI3407.PV_quality
# Qtd good: 2050618       Qtd bad: 3466873       Good Percent: 37.17
#
# TI3408.PV_quality
# Qtd good: 1986405       Qtd bad: 3531086       Good Percent: 36.00
#
# TI3409.PV_quality
# Qtd good: 2180114       Qtd bad: 191331       Good Percent: 91.93
#
# TI3410.PV_quality
# Qtd good: 2341603       Qtd bad: 29842       Good Percent: 98.74
#
# TI3411A.PV_quality
# Qtd good: 2299112       Qtd bad: 72333       Good Percent: 96.95
#
# TI3411B.PV_quality
# Qtd good: 2309452       Qtd bad: 61993       Good Percent: 97.39
#
# TI3411C.PV_quality
# Qtd good: 2278423       Qtd bad: 93022       Good Percent: 96.08
#
# TI3412A.PV_quality
# Qtd good: 2301207       Qtd bad: 70238       Good Percent: 97.04
#
# TI3412B.PV_quality
# Qtd good: 2302636       Qtd bad: 68809       Good Percent: 97.10

# %% [markdown]
# Qualidadade das tags 'TI3405', 'TI3406', 'TI3407' e 'TI3408' é preocupante.

# %% [markdown]
# ### 5. Pressão

# %% [markdown]
# #### 5.1. Lendo as tags

# %%
df = read_tags(pressao, path(''))
df.to_csv(path_3('df_pressao.csv.gz'), compression = 'gzip')
# Out:
# Processando TAG: PDI3413.PV
# Processando TAG: PDI3414.PV
# Processando TAG: PI3401.PV
# Processando TAG: PI3406.PV
# Processando TAG: PI3417.PV
# Processando TAG: PIC3002.MODE
# Processando TAG: PIC3002.OUT
# Processando TAG: PIC3002.PV
# Processando TAG: PIC3002.SP
# Concatenando...
# Feito!

# %% [markdown]
# #### 5.2. Análises estatísticas

# %%
estatisticas(df[df.columns[~df.columns.str.contains('_quality')]])
# Out:
#                    mean    min      max  percentNan
# PDI3413.PV     2.731691 -0.984    5.001    0.424142
# PDI3414.PV          NaN    NaN      NaN  100.000000
# PI3401.PV      1.574627 -0.558    6.180    0.424142
# PI3406.PV     23.616342 -0.800   31.935   57.443646
# PI3417.PV      5.122363 -1.537    9.030    0.424124
# PIC3002.MODE   1.231496  0.000    2.000    0.000000
# PIC3002.OUT    9.552065  0.000  100.000    0.424142
# PIC3002.PV     1.479957 -2.499    6.004    0.424142
# PIC3002.SP     1.431247  0.000    2.000    0.424142

# %% [markdown]
# A tag 'PDI3414.PV' está totalmente vazia, uma vez que todos os seus valores são '??????????'.

# %% [markdown]
# #### 5.3. Anos das tags

# %%
# criando um dataframe novo cujo index são os anos
df_ano = df.copy()
df_ano.index = df_ano.index.year

# %%
# removendo as colunas de qualidade
df_ano_numerico = df_ano[df_ano.columns[~df_ano.columns.str.contains('_quality')]]

# %%
tempo = time.time()
sns.heatmap(df_ano_numerico.isnull(), cbar = False)

# %% [markdown]
# Como dito anteriormente, a tag 'PDI3414.PV' está totalmente vazia, uma vez que todos os seus valores são '??????????'.

# %%
time.time() - tempo
# Out:
# 59.54992198944092

# %% [markdown]
# #### 5.4. Análises de qualidade

# %%
qualidade(df)
# Out:
# PDI3413.PV_quality
# Qtd good: 5311952       Qtd bad: 205539       Good Percent: 96.27
#
# PDI3414.PV_quality
# Qtd good: 0       Qtd bad: 5517491       Good Percent: 0.00
#
# PI3401.PV_quality
# Qtd good: 5466696       Qtd bad: 50795       Good Percent: 99.08
#
# PI3406.PV_quality
# Qtd good: 2341395       Qtd bad: 30050       Good Percent: 98.73
#
# PI3417.PV_quality
# Qtd good: 5462520       Qtd bad: 54971       Good Percent: 99.00
#
# PIC3002.MODE_quality
# Qtd good: 5203706       Qtd bad: 313785       Good Percent: 94.31
#
# PIC3002.OUT_quality
# Qtd good: 5467632       Qtd bad: 49859       Good Percent: 99.10
#
# PIC3002.PV_quality
# Qtd good: 5467587       Qtd bad: 49904       Good Percent: 99.10
#
# PIC3002.SP_quality
# Qtd good: 5467672       Qtd bad: 49819       Good Percent: 99.10

# %% [markdown]
# Como todos os valores de 'PDI3414.PV' são '??????????', todos eles foram classificados como 'Bad'.

# %% [markdown]
# ### 6. Vibração

# %% [markdown]
# #### 6.1. Lendo tags

# %%
df = read_tags(vibracao, path(''))
df.to_csv(path_3('df_vibracao.csv.gz'), compression = 'gzip')
# Out:
# Processando TAG: XA3401.PV
# Processando TAG: XI3403.PV
# Processando TAG: XI3404.PV
# Processando TAG: XI3405.PV
# Processando TAG: XI3406.PV
# Concatenando...
# Feito!

# %% [markdown]
# #### 6.2. Análises estatísticas

# %%
estatisticas(df[df.columns[~df.columns.str.contains('_quality')]])
# Out:
#                mean  min     max  percentNan
# XA3401.PV       NaN  NaN     NaN  100.000000
# XI3403.PV  4.413410 -0.4  19.866   57.443628
# XI3404.PV  5.201737 -0.4  19.871   57.443628
# XI3405.PV  1.775360 -0.4  20.400   57.443628
# XI3406.PV  4.293753 -0.4  18.697   57.443628

# %% [markdown]
# A tag 'XA3401.PV' está vazia, uma vez que todos os seus valores são 'ALARME'.

# %% [markdown]
# #### 6.3. Anos das tags

# %%
# criando um dataframe novo cujo index são os anos
df_ano = df.copy()
df_ano.index = df_ano.index.year

# %%
# removendo as colunas de qualidade
df_ano_numerico = df_ano[df_ano.columns[~df_ano.columns.str.contains('_quality')]]

# %%
tempo = time.time()
sns.heatmap(df_ano_numerico.isnull(), cbar = False)

# %%
time.time() - tempo
# Out:
# 33.0895459651947

# %% [markdown]
# #### 6.4. Análises de qualidade

# %%
qualidade(df)
# Out:
# XA3401.PV_quality
# Qtd good: 5257868       Qtd bad: 259623       Good Percent: 95.29
#
# XI3403.PV_quality
# Qtd good: 2342629       Qtd bad: 28816       Good Percent: 98.78
#
# XI3404.PV_quality
# Qtd good: 2342629       Qtd bad: 28816       Good Percent: 98.78
#
# XI3405.PV_quality
# Qtd good: 2342629       Qtd bad: 28816       Good Percent: 98.78
#
# XI3406.PV_quality
# Qtd good: 2342629       Qtd bad: 28816       Good Percent: 98.78

# %% [markdown]
# ### 7. Vazão

# %% [markdown]
# #### 7.1. Lendo tags

# %%
df = read_tags(vazao, path(''))
df.to_csv(path_3('df_vazao.csv.gz'), compression = 'gzip')
# Out:
# Processando TAG: FI3402.PV
# Processando TAG: FIC2601.MODE
# Processando TAG: FIC2601.OUT
# Processando TAG: FIC2601.PV
# Processando TAG: FIC2601.SP
# Concatenando...
# Feito!

# %% [markdown]
# #### 7.2. Análises estatísticas

# %%
estatisticas(df[df.columns[~df.columns.str.contains('_quality')]])
# Out:
#                    mean  min      max  percentNan
# FI3402.PV      8.647621  0.0   25.413    0.424142
# FIC2601.MODE   1.151987  0.0    5.000    0.000000
# FIC2601.OUT   22.912759  0.0  100.000    0.424142
# FIC2601.PV     8.458121 -2.8   14.337    0.424142
# FIC2601.SP     8.224742  0.0   14.000    0.424142

# %% [markdown]
# #### 7.3. Anos das tags

# %%
# criando um dataframe novo cujo index são os anos
df_ano = df.copy()
df_ano.index = df_ano.index.year

# %%
# removendo as colunas de qualidade
df_ano_numerico = df_ano[df_ano.columns[~df_ano.columns.str.contains('_quality')]]

# %%
tempo = time.time()
sns.heatmap(df_ano_numerico.isnull(), cbar = False)

# %%
time.time() - tempo
# Out:
# 73.70846581459045

# %% [markdown]
# #### 7.4. Análises de qualidade

# %%
qualidade(df)
# Out:
# FI3402.PV_quality
# Qtd good: 5422931       Qtd bad: 94560       Good Percent: 98.29
#
# FIC2601.MODE_quality
# Qtd good: 5317062       Qtd bad: 200429       Good Percent: 96.37
#
# FIC2601.OUT_quality
# Qtd good: 5458193       Qtd bad: 59298       Good Percent: 98.93
#
# FIC2601.PV_quality
# Qtd good: 5458099       Qtd bad: 59392       Good Percent: 98.92
#
# FIC2601.SP_quality
# Qtd good: 5458193       Qtd bad: 59298       Good Percent: 98.93

# %% [markdown]
# ### 8. Fração molar dos gases

# %% [markdown]
# #### 8.1. Lendo tags

# %%
df = read_tags(gas, path(''))
df.to_csv(path_3('df_gas.csv.gz'), compression = 'gzip')
# Out:
# Processando TAG: AI23212.PV
# Processando TAG: AI23422.PV
# Processando TAG: AI23432.PV
# Processando TAG: AI23442.PV
# Processando TAG: AI23452.PV
# Processando TAG: AI23462.PV
# Processando TAG: AI23472.PV
# Processando TAG: AI23482.PV
# Processando TAG: AI23492.PV
# Processando TAG: AI25121.PV
# Processando TAG: AI25131.PV
# Processando TAG: AI25141.PV
# Processando TAG: AI25151.PV
# Processando TAG: AI25161.PV
# Processando TAG: AI25171.PV
# Processando TAG: AI25181.PV
# Processando TAG: AI25191.PV
# Processando TAG: AI25211.PV
# Concatenando...
# Feito!

# %% [markdown]
# #### 8.2. Análises estatísticas

# %%
estatisticas(df[df.columns[~df.columns.str.contains('_quality')]])
# Out:
#                  mean     min      max  percentNan
# AI23212.PV   7.317609   0.000   50.000    0.860681
# AI23422.PV  27.722772   0.000   65.625    0.424142
# AI23432.PV   9.944734   0.000   36.758    0.424160
# AI23442.PV   0.058632   0.000   10.000    0.424160
# AI23452.PV  35.623032   0.000  100.000    0.424160
# AI23462.PV   7.563998   0.000   35.000    0.424160
# AI23472.PV   0.492110   0.000   10.000    0.424160
# AI23482.PV   3.990861   0.000   20.000    0.424142
# AI23492.PV   0.247754   0.000   20.000    0.424142
# AI25121.PV  25.587503   0.000   70.000    0.424142
# AI25131.PV   9.086096 -27.029   50.000    0.424160
# AI25141.PV   0.044510   0.000   10.000    0.424160
# AI25151.PV  30.743657 -11.554  100.000    0.424160
# AI25161.PV   6.932162   0.000   35.000    0.424160
# AI25171.PV   0.505975  -5.268   10.000    0.424160
# AI25181.PV   3.551924  -2.824   20.000    0.424142
# AI25191.PV   0.199784   0.000   10.000    0.424142
# AI25211.PV   7.993382   0.000   50.000    0.860681

# %% [markdown]
# #### 8.3. Anos das tags

# %%
# criando um dataframe novo cujo index são os anos
df_ano = df.copy()
df_ano.index = df_ano.index.year

# %%
# removendo as colunas de qualidade
df_ano_numerico = df_ano[df_ano.columns[~df_ano.columns.str.contains('_quality')]]

# %%
tempo = time.time()
sns.heatmap(df_ano_numerico.isnull(), cbar = False)

# %%
time.time() - tempo
# Out:
# 291.1225712299347

# %% [markdown]
# #### 8.4. Análises de qualidade

# %%
qualidade(df)
# Out:
# AI23212.PV_quality
# Qtd good: 5397541       Qtd bad: 119950       Good Percent: 97.83
#
# AI23422.PV_quality
# Qtd good: 5464124       Qtd bad: 53367       Good Percent: 99.03
#
# AI23432.PV_quality
# Qtd good: 5462934       Qtd bad: 54557       Good Percent: 99.01
#
# AI23442.PV_quality
# Qtd good: 5462942       Qtd bad: 54549       Good Percent: 99.01
#
# AI23452.PV_quality
# Qtd good: 5462934       Qtd bad: 54557       Good Percent: 99.01
#
# AI23462.PV_quality
# Qtd good: 5462933       Qtd bad: 54558       Good Percent: 99.01
#
# AI23472.PV_quality
# Qtd good: 5462950       Qtd bad: 54541       Good Percent: 99.01
#
# AI23482.PV_quality
# Qtd good: 5453764       Qtd bad: 63727       Good Percent: 98.85
#
# AI23492.PV_quality
# Qtd good: 5453764       Qtd bad: 63727       Good Percent: 98.85
#
# AI25121.PV_quality
# Qtd good: 5464113       Qtd bad: 53378       Good Percent: 99.03
#
# AI25131.PV_quality
# Qtd good: 5462929       Qtd bad: 54562       Good Percent: 99.01
#
# AI25141.PV_quality
# Qtd good: 5462929       Qtd bad: 54562       Good Percent: 99.01
#
# AI25151.PV_quality
# Qtd good: 5462930       Qtd bad: 54561       Good Percent: 99.01
#
# AI25161.PV_quality
# Qtd good: 5462929       Qtd bad: 54562       Good Percent: 99.01
#
# AI25171.PV_quality
# Qtd good: 5462928       Qtd bad: 54563       Good Percent: 99.01
#
# AI25181.PV_quality
# Qtd good: 5453730       Qtd bad: 63761       Good Percent: 98.84
#
# AI25191.PV_quality
# Qtd good: 5453766       Qtd bad: 63725       Good Percent: 98.85
#
# AI25211.PV_quality
# Qtd good: 5431387       Qtd bad: 86104       Good Percent: 98.44

# %% [markdown]
# ### 9. Outras

# %% [markdown]
# #### 9.1. Lendo tags

# %%
df = read_tags(outras, path(''))
df[df.columns[~df.columns.str.contains('_quality')]] = df[df.columns[~df.columns.str.contains('_quality')]].apply(pd.to_numeric, errors = 'coerce')
# Out:
# Processando TAG: EcompC302A.PV
# Processando TAG: EpolC302A-1.PV
# Processando TAG: EpolC302A-2.PV
# Processando TAG: EpolC302A.PV
# Processando TAG: EvolC302A-1.PV
# Processando TAG: EvolC302A-2.PV
# Processando TAG: EvolC302A.PV
# Processando TAG: HeadC302A-1.PV
# Processando TAG: HeadC302A-2.PV
# Processando TAG: HeadC302A.PV
# Processando TAG: JI3401.PV
# Concatenando...
# Feito!

# %% [markdown]
# #### 9.2. Análises estatísticas

# %%
estatisticas(df[df.columns[~df.columns.str.contains('_quality')]])
# Out:
#                  mean     min      max  percentNan
# AI23212.PV   7.317609   0.000   50.000    0.860681
# AI23422.PV  27.722772   0.000   65.625    0.424142
# AI23432.PV   9.944734   0.000   36.758    0.424160
# AI23442.PV   0.058632   0.000   10.000    0.424160
# AI23452.PV  35.623032   0.000  100.000    0.424160
# AI23462.PV   7.563998   0.000   35.000    0.424160
# AI23472.PV   0.492110   0.000   10.000    0.424160
# AI23482.PV   3.990861   0.000   20.000    0.424142
# AI23492.PV   0.247754   0.000   20.000    0.424142
# AI25121.PV  25.587503   0.000   70.000    0.424142
# AI25131.PV   9.086096 -27.029   50.000    0.424160
# AI25141.PV   0.044510   0.000   10.000    0.424160
# AI25151.PV  30.743657 -11.554  100.000    0.424160
# AI25161.PV   6.932162   0.000   35.000    0.424160
# AI25171.PV   0.505975  -5.268   10.000    0.424160
# AI25181.PV   3.551924  -2.824   20.000    0.424142
# AI25191.PV   0.199784   0.000   10.000    0.424142
# AI25211.PV   7.993382   0.000   50.000    0.860681

# %% [markdown]
# #### 9.3. Anos das tags

# %%
# criando um dataframe novo cujo index são os anos
df_ano = df.copy()
df_ano.index = df_ano.index.year

# %%
# removendo as colunas de qualidade
df_ano_numerico = df_ano[df_ano.columns[~df_ano.columns.str.contains('_quality')]]

# %%
tempo = time.time()
sns.heatmap(df_ano_numerico.isnull(), cbar = False)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-52-97c85bfa67b2> in <module>
#       1 tempo = time.time()
# ----> 2 sns.heatmap(df_ano_numerico.isnull(), cbar = False)
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     526     if square:
#     527         ax.set_aspect("equal")
# --> 528     plotter.plot(ax, cbar_ax, kwargs)
#     529     return ax
#     530
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\matrix.py in plot(self, ax, cax, kws)
#     282         # Draw the heatmap
#     283         mesh = ax.pcolormesh(self.plot_data, vmin=self.vmin, vmax=self.vmax,
# --> 284                              cmap=self.cmap, **kws)
#     285
#     286         # Set the axis limits
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in pcolormesh(self, alpha, norm, cmap, vmin, vmax, shading, antialiased, *args, **kwargs)
#    5980         allmatch = (shading == 'gouraud')
#    5981
# -> 5982         X, Y, C = self._pcolorargs('pcolormesh', *args, allmatch=allmatch)
#    5983         Ny, Nx = X.shape
#    5984         X = X.ravel()
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in _pcolorargs(funcname, allmatch, *args)
#    5528                 X, Y = np.meshgrid(np.arange(numCols + 1),
#    5529                                    np.arange(numRows + 1))
# -> 5530             C = cbook.safe_masked_invalid(C)
#    5531             return X, Y, C
#    5532
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\cbook\__init__.py in safe_masked_invalid(x, copy)
#     791
#     792     try:
# --> 793         xm = np.ma.masked_invalid(x, copy=False)
#     794         xm.shrink_mask()
#     795     except TypeError:
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\ma\core.py in masked_invalid(a, copy)
#    2359     mask = getattr(a, '_mask', None)
#    2360     if mask is not None:
# -> 2361         condition = ~(np.isfinite(getdata(a)))
#    2362         if mask is not nomask:
#    2363             condition |= mask
#
# MemoryError:

# %%
time.time() - tempo

# %% [markdown]
# #### 9.4. Análises de qualidade

# %%
qualidade(df)
