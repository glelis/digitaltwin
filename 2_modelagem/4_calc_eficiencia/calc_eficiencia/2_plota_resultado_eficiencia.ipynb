# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import time
import missingno as msno

# %run ..\..\..\..\funcoes_base_global\funcoes_plot.py
# %run ..\..\..\..\funcoes_base_global\plot_distribuicao_anual.py

# %%
input_path  = os.path.join('out','')
output_path = os.path.join('out','')
if not os.path.exists(output_path): 
    os.mkdir(output_path)

# %%
df = pd.read_csv(input_path+'df_eficiencia.csv.gz', compression = 'gzip', parse_dates = ['Date'], index_col = 'Date')

# %%
df.head()
# Out:
#                      Ef_Politropica  Head_Politropica  Ef_Isentropica  \
# Date
# 2015-01-06 05:00:00       70.216953         65.470738       67.838724
# 2015-01-06 05:01:00       68.710337         65.784760       66.217385
# 2015-01-06 05:02:00       68.292867         66.192728       65.753966
# 2015-01-06 05:03:00       69.281777         66.724619       66.805655
# 2015-01-06 05:04:00       70.374286         67.650892       67.946654
#
#                      Head_Isentropica     Z_Suc    Z_Desc         MW    T_Suc  \
# Date
# 2015-01-06 05:00:00         63.253262  0.950720  0.932259  42.550343  306.150
# 2015-01-06 05:01:00         63.397954  0.950546  0.933369  42.550343  307.145
# 2015-01-06 05:02:00         63.731904  0.950125  0.933077  42.550343  307.150
# 2015-01-06 05:03:00         64.339890  0.950291  0.932515  42.550343  308.144
# 2015-01-06 05:04:00         65.317206  0.949326  0.930053  42.550343  308.150
#
# ...

# %%
tempo = time.time()
sns.heatmap(df.isnull(), cbar = False)

# %%
plot_distribuicao_anual(df[(df['Ef_Politropica'] < 150) & (df['Ef_Politropica'] > -10)],'Ef_Politropica',save_dir='')

# %%
plot_distribuicao_anual(df[(df['Ef_Politropica'] < 150) & (df['Ef_Politropica'] > -10)],'Ef_Isentropica',save_dir='')

# %%
plot_distribuicao_anual(df[(df['Ef_Politropica'] < 150) & (df['Ef_Politropica'] > -10)],'Densidade_Suc',save_dir='')

# %%
plot_distribuicao_anual(df[(df['Ef_Politropica'] < 150) & (df['Ef_Politropica'] > -10)],'Densidade_Desc',save_dir='')

# %%
start_date ='2014-01-01 00:00:00'
end_date = '2020-01-01 23:59:00'
days_interval = 30
minutes_interval = 60*12
roling = [60*24*7]

tags = ['Ef_Politropica', 'Ef_Isentropica', 'Densidade_Suc', 'Densidade_Desc']

filtro  = (df['Ef_Politropica'] < 300) & (df['Ef_Politropica'] > -10)

for tag in tags:
    plot_variables_rolling_V2(df[filtro],[tag],legend=[tag],reference_line=[],
                           rolling_time=roling,
                           minutes_interval=minutes_interval,start_date=start_date,end_date=end_date,days_interval=days_interval);
# Out:
# (1794717, 1)
# (1794717, 1)
# (1794717, 1)
# (1794717, 1)

# %%
start_date ='2016-01-01 00:00:00'
end_date = '2017-01-01 23:59:00'
days_interval = 30
minutes_interval = 60*12
roling = [7*60*24]

tags = ['Ef_Politropica', 'Ef_Isentropica', 'Densidade_Suc', 'Densidade_Desc']

filtro  = (df['Ef_Politropica'] < 300) & (df['Ef_Politropica'] > -10)

for tag in tags:
    plot_variables_rolling_V2(df[filtro],[tag],legend=[tag],reference_line=[],
                           rolling_time=roling,
                           minutes_interval=minutes_interval,start_date=start_date,end_date=end_date,days_interval=days_interval);
# Out:
# (303164, 1)
# (303164, 1)
# (303164, 1)
# (303164, 1)

# %%
start_date ='2017-01-01 00:00:00'
end_date = '2018-01-01 23:59:00'
days_interval = 30
minutes_interval = 60*12
roling = [7*60*24]

tags = ['Ef_Politropica', 'Ef_Isentropica', 'Densidade_Suc', 'Densidade_Desc']

filtro  = (df['Ef_Politropica'] < 300) & (df['Ef_Politropica'] > -10)

for tag in tags:
    plot_variables_rolling_V2(df[filtro],[tag],legend=[tag],reference_line=[],
                           rolling_time=roling,
                           minutes_interval=minutes_interval,start_date=start_date,end_date=end_date,days_interval=days_interval);
# Out:
# (501309, 1)
# (501309, 1)
# (501309, 1)
# (501309, 1)

# %%
start_date ='2018-01-01 00:00:00'
end_date = '2019-01-01 23:59:00'
days_interval = 30
minutes_interval = 60*12
roling = [7*60*24]

tags = ['Ef_Politropica', 'Ef_Isentropica', 'Densidade_Suc', 'Densidade_Desc']

filtro  = (df['Ef_Politropica'] < 300) & (df['Ef_Politropica'] > -10)

for tag in tags:
    plot_variables_rolling_V2(df[filtro],[tag],legend=[tag],reference_line=[],
                           rolling_time=roling,
                           minutes_interval=minutes_interval,start_date=start_date,end_date=end_date,days_interval=days_interval);
# Out:
# (392510, 1)
# (392510, 1)
# (392510, 1)
# (392510, 1)
